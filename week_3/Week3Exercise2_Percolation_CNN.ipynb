# %% [markdown]
# # Comparing architectures

# %% [markdown]
# The aim of this practical is to use a new synthetic dataset: percolations through a rectangle, explained below.
#
# The advantage of using this dataset is that the inputs are small, so that the neural nets can be small but deep, and it is possible for you to compare many different net designs quickly, training only with a cpu.
#
# But the concept of percolation is 'deep': there is no simple logical description of when there is a percolating path across a rectangle. Logistic regression fails completely.  There are many paths from one side of the square to the other, and the neural network needs to be able to recognise all of them. The function required to do this is highly non-linear, and there are dependencies between more than 8 values in a 8x8 square.
#
# Ironically, there is a simple iterative Python function that easily computes whether a matrix percolates, using depth first search. This is very quick, uses little computation, and it is 100% accurate.
#
#
# Percolation is not an easy property for neural nets to recognise. Nobody has yet managed to design a neural net that gets 100% accuracy !! Even after 30,000 training examples...   I challenge you to try !

# %% [markdown]
# # Percolation data

# %% [markdown]
# To define some image data, we will consider small images, initially of size 8x8 in black and white (or 0 and 1).
#
# The first concept that we will try to teach a NN is whether there is a continuous path of "white" pixels between the two sides of the image.
#
# The function `percolate` returns True is there is a continuous path between the left and right sides of a binary image. (Aspects of python that are used are sets, a while loop, and break. )

# %%
import numpy as np

import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from random import randint

# %%
# this function does a depth-first search across a matrix of 0s and 1s, 
# looking for a path of 1s between the first and last columns of the matrix
# such a path is called a 'percolation path'

def percolate( mat ):
    """
    Returns True if there is a percolation path of 1s from col 0 col -1 of a matrix of 0s and 1s
    """
    nrows = mat.shape[0]
    ncols = mat.shape[1]
    frontier = set()
    for i in range(0,nrows):
        if mat[i,0]:
            frontier.add( (i,0) )
    explored = set()
    flag = False # this will be returned if the frontier becomes empty without finding a
                 # filled pixel in the right-most column
    while frontier: # frontier evaluates to True in this context if it is non-empty
        r,c = frontier.pop()
        explored.add( (r,c) )
        if r > 0: # North
            if mat[r-1,c]:
                coords = (r-1,c)
                if coords not in explored: 
                    if coords not in frontier: # this order of testing is necessary since each element of explored has been in frontier
                        frontier.add( coords )
        if c < ncols-1: # East
            if mat[r,c+1]:
                if c+1 == mat.shape[1]-1 : # Hurray, we have percolated to the last column
                    flag = True
                    break
                coords = (r,c+1)
                if coords not in explored: 
                    if coords not in frontier: # this order of testing is necessary since each element of explored has been in frontier
                        frontier.add( coords )
        if r < nrows-1: # South
            if mat[r+1,c]:
                coords = (r+1,c)
                if coords not in explored: 
                    if coords not in frontier: # this order of testing is necessary since each element of explored has been in frontier
                        frontier.add( coords )
        if c > 0: # West
            if mat[r,c-1]:
                coords = (r,c-1)
                if coords not in explored: 
                    if coords not in frontier: # this order of testing is necessary since each element of explored has been in frontier
                        frontier.add( coords )
    return flag

# %% [markdown]
# Now test the percolate function. We will generate random images with a probability 0.6 probability of 1 in each pixel.

# %%
tmp = np.random.random([8,8]) > 0.4

plt.imshow(tmp), percolate(tmp)

# the first result is an image; the second result is True if there is a continuous path of yellow squares from the left to
# the right side of the image. The path is continuous if the yellow squares are joined at one side: two yellow squares 
# at a corner do not count as joined in a path

# you can evaluate this cell many times, and each time look at the resulting plot and answer, to check that you 
# understand the notion of percolation, and also that the `percolate` function is getting it right !
# Out:
# (<matplotlib.image.AxesImage at 0x115be1a60>, True)

# %%
# How many 8x8 binary patterns are there? 

2.0**64
# Out:
# 1.8446744073709552e+19

# %% [markdown]
# More than 18 billion, so our NN will need to generalise, because we will give it training sets of far fewer than 18 billion examples.

# %% [markdown]
# # Construct datasets
#
# The joy of synthetic data is that we can construct as much of it as we want...

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F  # this includes tensor functions that we can use in backwards pass
import torchvision
import torchvision.datasets as datasets
from torchvision import transforms
import torch.optim as optim

# %%
def make_percolation_dataset(side=8,threshold=0.42,n_examples=10):
    """
    This function generates an array of random images, in the form needed for Keras, and 
    then labels them as percolati# ng or not, using the percolate function. Roughly 50% of the
    images will have class 1 (percolating), so the dataset is likely to be reasonably balanced. 
    """
    X_data = (np.random.random([n_examples,side,side,1]) > threshold).astype(float) 
    Y_data = np.zeros([n_examples,1])
    for i in range(0,n_examples):
        if percolate(X_data[i,:,:,0]):
            Y_data[i,0] = 1
    return [(torch.tensor(x.astype(np.float32)).reshape(1,8,8), torch.tensor(float(y)).reshape(1) )  for x,y in zip( X_data, Y_data)]

# the types of the numbers in the tensors need to be float32: the most natural place to do this data conversion
# is in generating the datasets.

# %%
training_set = make_percolation_dataset( n_examples = 1000 )
test_set = make_percolation_dataset( n_examples = 1000 )

# %% [markdown]
# When we make a dataset, we should always check how many there are of each class:

# %%
# this calculates the fraction of positive examples in the training set
sum( [ x[1].item() for x in training_set ] ) / len( training_set)
# Out:
# 0.484

# %% [markdown]
# The fraction of positive examples should ideally be close to 0.5  -- the default probability that a pixel is equal to 1 was chosen to ensure this.

# %%
# check that a random element of the training set is correctly labelled
x,y = training_set[376]
plt.imshow(x.numpy().squeeze() ), y  # check a random element of the training set to see it is correct
# we need to squeeze the
# Out:
# (<matplotlib.image.AxesImage at 0x125f684f0>, tensor([0.]))

# %% [markdown]
# If there is a continuous yellow path from the left side to the right side of the image, then the image "percolates" and the y value should be 1, otherwise the y value should be 0.

# %% [markdown]
# # Constructing and training models

# %% [markdown]
# ### A naive fully connected  Dense model for detecting percolation

# %% [markdown]
# (For tutorial purposes) the first thing to try is a naive model which pays no attention to the image structure. I don't expect this type of model to work well - but you may find a way to surprise me.
#
# In the model defined below, we flatten the image to a single row of values, and then we put in a single layer of neurons, each one of which is connected to all of the inputs. In other words, each neuron in this layer has 64 inputs, and then there is a final neuron which gives the output.
#
# You will (I hope) find that this is a terrible architecture for this problem. You will find that if there are too few neurons, then the model cannot even fit the training data.  If there are too many neurons in the Dense layer, then the model will fit the training data, but fail almost completely on the validation data: that is, the model will overfit badly.
#
# What would be the only way to get this poorly designed model to work? *Use a lot of training data!* . You can try constructing a much larger training set, and then see if you can get this model to classify correctly.  I doubt it - but you might succeed.
#
# Does adding more dense layers help?  Does adding regularisation - either `l1`, `l2`, or dropout - help?

# %%
# our simplest neural net - it is just going to be a linear layer and then sigmoid 
# (equivalent to softmax when there are only two classes)
# This is simply logistic regression. We expect it to do badly on validation data, but it 
# may overfit  training data
class NN1( nn.Module ):
    
    def __init__(self): 
        super(NN1, self).__init__()
        self.layers = nn.Sequential( 
            nn.Flatten(), 
            nn.Linear(64,1),
            nn.Sigmoid())  # a linear layer (a matrix, plus biases) with 784 inputs and 10 outputs
             # if we are going to make probabilistic categorical predictions, it is more flexible to allow unnormalised 
             # outputs, because we can use  different functions for the predictions and and in calculating the loss, as 
             # we shall soon see
    
    
    def forward( self, x ): # computes the forward pass ... this one is particularly simple
        x = self.layers( x )
        return x

# %%
net = NN1() 
# the first time I coded this, I thought nn would be a good name for the network,
# but unfortunately it masks the PyTorch nn module .... so I am using net instead

# %%
net.layers
# Out:
# Sequential(
#   (0): Flatten()
#   (1): Linear(in_features=64, out_features=1, bias=True)
#   (2): Sigmoid()
# )

# %%
# the state_dict is a useful attribute of a Model, 
# which contains convenient names as keys for all the tensors
net.state_dict()
# Out:
# OrderedDict([('layers.1.weight',
#               tensor([[ 0.0349,  0.1005,  0.0092,  0.1054, -0.0274,  0.0317, -0.0323,  0.0664,
#                        -0.0596,  0.0494,  0.0951,  0.0490,  0.0833, -0.0993, -0.0221,  0.1024,
#                         0.0339,  0.0144,  0.0567,  0.0034,  0.0926,  0.0959,  0.0595, -0.0720,
#                        -0.0383, -0.0945,  0.0474, -0.0330, -0.0200, -0.0721, -0.0991, -0.0121,
#                        -0.0449,  0.0179, -0.0169, -0.0492,  0.0474,  0.0902, -0.1212,  0.0846,
#                        -0.0979,  0.1034, -0.0604,  0.1101, -0.1119, -0.0127,  0.0700,  0.0733,
#                        -0.0878, -0.0742,  0.0094,  0.0079,  0.0376,  0.0407,  0.0390,  0.0593,
#                         0.0294, -0.0765, -0.0168,  0.0190, -0.0293,  0.0253,  0.1035, -0.0981]])),
#              ('layers.1.bias', tensor([-0.1238]))])

# %% [markdown]
# Now we will go step by step through all the stages of constructing a NN training loop, before putting it all together.

# %%
# DataLoader is a useful utility class provided by pytorch for extracting minibatches from 
# a large dataset. 

trainloader = torch.utils.data.DataLoader( training_set, batch_size=4, shuffle=True)
testloader = torch.utils.data.DataLoader( test_set, batch_size=4, shuffle=True)

# if you want to change the batch size, you need to define a new dataloader: 
# the dataloader is a lightweight class that just provides iteration over the dataset

# %%
# we construct a (temporary) iterator from trainloader, and get the first minibatch
tmpiter = iter(trainloader)

images, labels = next(tmpiter)  # the minibatch is a list of [images, labels]

# let's check what form the images and labels come in

# %%
labels
# Out:
# tensor([[0.],
#         [0.],
#         [0.],
#         [0.]])

# %%
images.shape # always check the shapes of your tensors...
# Out:
# torch.Size([4, 1, 8, 8])

# %%
net.forward( images ) # does our nn work? What does it produce?
# Out:
# tensor([[0.5540],
#         [0.3635],
#         [0.6186],
#         [0.4746]], grad_fn=<SigmoidBackward>)

# %% [markdown]
# ### Which loss function?
#
# We will use log-loss, because we are predicting classes (0 and 1, non-percolating and percolating).
#
# We could use two outputs, produced by softmax, and cross-entropy loss, as we did for MNIST.
#
# But then we have highly redundant output weights: this may (I am not sure)
#
# We can equivalently use one sigmoid neuron as output: the output of this neuron is the predicted probability of 1.
#
# The loss function is provided by PyTorch: BCELoss.  Look at its documentation on the PyTorch site.

# %%
# BCELoss is binary cross entropy loss: 
# this takes a single probability (as output by a sigmoid neuron for example)
loss_function = nn.BCELoss() 

# note that the result of loss function is a one element tensor: it needs to be 
# tensor because we start the backward pass from the loss.

# %%
loss_function( net.forward( images ), labels )
# Out:
# tensor(0.7167, grad_fn=<BinaryCrossEntropyBackward>)

# %% [markdown]
# -Log( 0.5 ) = 0.69, so we expect the average loss to be 0.7ish, as the network is not trained yet.

# %% [markdown]
# ### Calculating Accuracy
#
# How do we calculate accuracy, which is the percentage of correct predictions?
#
# We cound a sigmoid output that is > 0.5 as predicting a 1, and if it is < 0.5, as a prediction of 0.

# %%
result = net.forward(images)
result
# Out:
# tensor([[0.5540],
#         [0.3635],
#         [0.6186],
#         [0.4746]], grad_fn=<SigmoidBackward>)

# %%
result > 0.5
# Out:
# tensor([[ True],
#         [False],
#         [ True],
#         [False]])

# %%
labels > 0.5
# Out:
# tensor([[False],
#         [False],
#         [False],
#         [False]])

# %%
# This expression gives the sum of the number of correct predictions in the batch
# Note that we access the value of a zero-dimensional tensor with .item()

sum( (result > 0.5) == (labels > 0.5 ) ).item()
# Out:
# 2

# %%
# this function calculates the loss and error rate on the validation set
# assuming that the output of the neural net nn is a single prediction probability, from a single sigmoid neuron. 

def accuracy_and_loss( net, loss_function, dataloader ):
    total_correct = 0 
    total_loss = 0.0 
    total_examples = 0 
    n_batches = 0 
    with torch.no_grad():  # we do not neet to compute the gradients when making predictions on the validation set
        for data in dataloader: 
            images, labels = data
            outputs = net(images)
            batch_loss = loss_function(outputs, labels) # this is averaged over the batch
            n_batches += 1
            total_loss += batch_loss.item()
            total_correct += sum( (outputs > 0.5 ) == ( labels > 0.5 ) ).item() # number correct in the minibatch
            total_examples += labels.size(0) # the number of labels, which is just the size of the minibatch 
             
    
    accuracy = total_correct / total_examples
    mean_loss = total_loss / n_batches
    
    return ( accuracy, mean_loss )
    #print( "Accuracy on test set: %d %%" %(100 * correct/total_examples))

# %%
# Testing accuracy_and_loss

accuracy_and_loss( net, loss_function, testloader)
# Out:
# (0.514, 0.7006573820114136)

# %% [markdown]
# Accuracy should be 0.5ish, loss should be 0.7ish

# %% [markdown]
# ## Putting it all together: training a network

# %%
# This cell is our pattern for nn initialisation and training 
# In the next section we convert it into a function...

trainloader = torch.utils.data.DataLoader( training_set, batch_size=32, shuffle=True)
testloader = torch.utils.data.DataLoader( test_set, batch_size=32, shuffle=True)

net = NN1()
optimizer1 = optim.RMSprop( net.parameters(), lr=0.001 )

for epoch in range(200): # number of times to loop over the dataset
    total_loss = 0 
    total_correct = 0 
    total_examples = 0 
    n_mini_batches = 0
    
    for i, mini_batch in enumerate( trainloader, 0 ):
        images, labels = mini_batch
        
        # zero the parameter gradients
        # all the parameters that are being updated are in the optimizer, 
        # so if we zero the gradients of all the tensors in the optimizer, 
        # that is the safest way to zero all the gradients
        optimizer1.zero_grad()
        
        outputs = net(images) # this is the forward pass
        
        loss = loss_function ( outputs, labels )
        
        loss.backward() # does the backward pass and computes all gradients
        
        optimizer1.step() # does one optimisation step
        
        n_mini_batches += 1 # keep track of number of minibatches, and collect the loss for each minibatch
        total_loss += loss.item() # remember that the loss is a zero-order tensor
        # so that to extract its value, we use .item(), as we cannot index as there are no dimensions
        
        # keep track of number of examples, and collect number correct in each minibatch
        total_correct += sum( ( outputs > 0.5 ) == ( labels > 0.5 ) ).item()
        total_examples += len( labels )
        
    # calculate statistics for each epoch and print them. 
    # You can alter this code to accumulate these statistics into lists/vectors and plot them
    epoch_training_accuracy = total_correct / total_examples
    epoch_training_loss = total_loss / n_mini_batches
    
    val_accuracy, val_loss = accuracy_and_loss( net, loss_function, testloader )
    
    print('Epoch %d loss: %.3f acc: %.3f val_loss: %.3f val_acc: %.3f'
          %(epoch+1, epoch_training_loss, epoch_training_accuracy, val_loss, val_accuracy   ))
# Out:
# Epoch 1 loss: 0.700 acc: 0.510 val_loss: 0.694 val_acc: 0.536
# Epoch 2 loss: 0.688 acc: 0.541 val_loss: 0.695 val_acc: 0.521
# Epoch 3 loss: 0.688 acc: 0.547 val_loss: 0.692 val_acc: 0.540
# Epoch 4 loss: 0.682 acc: 0.558 val_loss: 0.693 val_acc: 0.541
# Epoch 5 loss: 0.682 acc: 0.557 val_loss: 0.692 val_acc: 0.532
# Epoch 6 loss: 0.678 acc: 0.567 val_loss: 0.692 val_acc: 0.537
# Epoch 7 loss: 0.677 acc: 0.572 val_loss: 0.693 val_acc: 0.525
# Epoch 8 loss: 0.673 acc: 0.591 val_loss: 0.693 val_acc: 0.534
# Epoch 9 loss: 0.672 acc: 0.575 val_loss: 0.689 val_acc: 0.532
# Epoch 10 loss: 0.670 acc: 0.592 val_loss: 0.691 val_acc: 0.530
# Epoch 11 loss: 0.671 acc: 0.588 val_loss: 0.689 val_acc: 0.528
# Epoch 12 loss: 0.667 acc: 0.583 val_loss: 0.689 val_acc: 0.532
# Epoch 13 loss: 0.669 acc: 0.597 val_loss: 0.690 val_acc: 0.531
# Epoch 14 loss: 0.666 acc: 0.602 val_loss: 0.689 val_acc: 0.533
# Epoch 15 loss: 0.666 acc: 0.610 val_loss: 0.688 val_acc: 0.529
# Epoch 16 loss: 0.663 acc: 0.602 val_loss: 0.689 val_acc: 0.533
# Epoch 17 loss: 0.665 acc: 0.603 val_loss: 0.688 val_acc: 0.531
# Epoch 18 loss: 0.662 acc: 0.606 val_loss: 0.688 val_acc: 0.536
# Epoch 19 loss: 0.661 acc: 0.602 val_loss: 0.686 val_acc: 0.539
# Epoch 20 loss: 0.659 acc: 0.595 val_loss: 0.690 val_acc: 0.545
# Epoch 21 loss: 0.660 acc: 0.604 val_loss: 0.687 val_acc: 0.535
# Epoch 22 loss: 0.659 acc: 0.602 val_loss: 0.689 val_acc: 0.545
# Epoch 23 loss: 0.656 acc: 0.608 val_loss: 0.687 val_acc: 0.532
# Epoch 24 loss: 0.654 acc: 0.621 val_loss: 0.688 val_acc: 0.544
# Epoch 25 loss: 0.654 acc: 0.604 val_loss: 0.688 val_acc: 0.544
# Epoch 26 loss: 0.656 acc: 0.606 val_loss: 0.691 val_acc: 0.536
# Epoch 27 loss: 0.655 acc: 0.617 val_loss: 0.690 val_acc: 0.540
# Epoch 28 loss: 0.655 acc: 0.614 val_loss: 0.689 val_acc: 0.538
# Epoch 29 loss: 0.654 acc: 0.610 val_loss: 0.687 val_acc: 0.547
# Epoch 30 loss: 0.653 acc: 0.613 val_loss: 0.688 val_acc: 0.533
# Epoch 31 loss: 0.655 acc: 0.609 val_loss: 0.688 val_acc: 0.537
# Epoch 32 loss: 0.652 acc: 0.625 val_loss: 0.688 val_acc: 0.545
# Epoch 33 loss: 0.653 acc: 0.624 val_loss: 0.690 val_acc: 0.539
# Epoch 34 loss: 0.653 acc: 0.618 val_loss: 0.688 val_acc: 0.534
# Epoch 35 loss: 0.650 acc: 0.616 val_loss: 0.690 val_acc: 0.530
# Epoch 36 loss: 0.649 acc: 0.615 val_loss: 0.689 val_acc: 0.544
# Epoch 37 loss: 0.646 acc: 0.618 val_loss: 0.689 val_acc: 0.537
# Epoch 38 loss: 0.652 acc: 0.622 val_loss: 0.690 val_acc: 0.544
# Epoch 39 loss: 0.648 acc: 0.611 val_loss: 0.693 val_acc: 0.543
# Epoch 40 loss: 0.646 acc: 0.613 val_loss: 0.690 val_acc: 0.541
# Epoch 41 loss: 0.647 acc: 0.619 val_loss: 0.691 val_acc: 0.541
# Epoch 42 loss: 0.648 acc: 0.617 val_loss: 0.690 val_acc: 0.540
# Epoch 43 loss: 0.650 acc: 0.623 val_loss: 0.688 val_acc: 0.539
# Epoch 44 loss: 0.648 acc: 0.627 val_loss: 0.695 val_acc: 0.547
# Epoch 45 loss: 0.647 acc: 0.631 val_loss: 0.689 val_acc: 0.540
# Epoch 46 loss: 0.649 acc: 0.616 val_loss: 0.689 val_acc: 0.543
# Epoch 47 loss: 0.646 acc: 0.620 val_loss: 0.689 val_acc: 0.546
# Epoch 48 loss: 0.646 acc: 0.623 val_loss: 0.686 val_acc: 0.541
# Epoch 49 loss: 0.644 acc: 0.621 val_loss: 0.688 val_acc: 0.541
# Epoch 50 loss: 0.646 acc: 0.621 val_loss: 0.691 val_acc: 0.539
# Epoch 51 loss: 0.644 acc: 0.625 val_loss: 0.688 val_acc: 0.535
# Epoch 52 loss: 0.641 acc: 0.621 val_loss: 0.688 val_acc: 0.545
# Epoch 53 loss: 0.644 acc: 0.631 val_loss: 0.689 val_acc: 0.535
# Epoch 54 loss: 0.644 acc: 0.623 val_loss: 0.689 val_acc: 0.548
# Epoch 55 loss: 0.646 acc: 0.629 val_loss: 0.691 val_acc: 0.553
# Epoch 56 loss: 0.645 acc: 0.630 val_loss: 0.688 val_acc: 0.534
# Epoch 57 loss: 0.642 acc: 0.630 val_loss: 0.691 val_acc: 0.539
# Epoch 58 loss: 0.643 acc: 0.628 val_loss: 0.691 val_acc: 0.544
# Epoch 59 loss: 0.640 acc: 0.635 val_loss: 0.688 val_acc: 0.537
# Epoch 60 loss: 0.639 acc: 0.635 val_loss: 0.691 val_acc: 0.545
# Epoch 61 loss: 0.639 acc: 0.637 val_loss: 0.689 val_acc: 0.544
# Epoch 62 loss: 0.640 acc: 0.633 val_loss: 0.692 val_acc: 0.544
# Epoch 63 loss: 0.641 acc: 0.635 val_loss: 0.694 val_acc: 0.540
# Epoch 64 loss: 0.640 acc: 0.635 val_loss: 0.691 val_acc: 0.543
# Epoch 65 loss: 0.638 acc: 0.623 val_loss: 0.691 val_acc: 0.542
# Epoch 66 loss: 0.641 acc: 0.640 val_loss: 0.691 val_acc: 0.543
# Epoch 67 loss: 0.642 acc: 0.635 val_loss: 0.692 val_acc: 0.543
# Epoch 68 loss: 0.640 acc: 0.633 val_loss: 0.691 val_acc: 0.542
# Epoch 69 loss: 0.640 acc: 0.635 val_loss: 0.689 val_acc: 0.542
# Epoch 70 loss: 0.642 acc: 0.624 val_loss: 0.691 val_acc: 0.541
# Epoch 71 loss: 0.639 acc: 0.635 val_loss: 0.694 val_acc: 0.542
# Epoch 72 loss: 0.637 acc: 0.630 val_loss: 0.690 val_acc: 0.541
# Epoch 73 loss: 0.641 acc: 0.634 val_loss: 0.688 val_acc: 0.536
# Epoch 74 loss: 0.638 acc: 0.628 val_loss: 0.694 val_acc: 0.552
# Epoch 75 loss: 0.637 acc: 0.635 val_loss: 0.690 val_acc: 0.544
# Epoch 76 loss: 0.637 acc: 0.637 val_loss: 0.692 val_acc: 0.541
# Epoch 77 loss: 0.634 acc: 0.637 val_loss: 0.690 val_acc: 0.546
# Epoch 78 loss: 0.638 acc: 0.635 val_loss: 0.688 val_acc: 0.545
# Epoch 79 loss: 0.635 acc: 0.637 val_loss: 0.688 val_acc: 0.539
# Epoch 80 loss: 0.637 acc: 0.634 val_loss: 0.692 val_acc: 0.541
# Epoch 81 loss: 0.634 acc: 0.640 val_loss: 0.695 val_acc: 0.537
# Epoch 82 loss: 0.634 acc: 0.632 val_loss: 0.688 val_acc: 0.544
# Epoch 83 loss: 0.633 acc: 0.639 val_loss: 0.696 val_acc: 0.537
# Epoch 84 loss: 0.630 acc: 0.641 val_loss: 0.692 val_acc: 0.546
# Epoch 85 loss: 0.633 acc: 0.635 val_loss: 0.692 val_acc: 0.542
# Epoch 86 loss: 0.632 acc: 0.632 val_loss: 0.694 val_acc: 0.546
# Epoch 87 loss: 0.636 acc: 0.638 val_loss: 0.689 val_acc: 0.542
# Epoch 88 loss: 0.633 acc: 0.643 val_loss: 0.693 val_acc: 0.557
# Epoch 89 loss: 0.635 acc: 0.641 val_loss: 0.696 val_acc: 0.555
# Epoch 90 loss: 0.637 acc: 0.642 val_loss: 0.689 val_acc: 0.539
# Epoch 91 loss: 0.636 acc: 0.634 val_loss: 0.696 val_acc: 0.549
# Epoch 92 loss: 0.634 acc: 0.641 val_loss: 0.690 val_acc: 0.554
# Epoch 93 loss: 0.635 acc: 0.638 val_loss: 0.689 val_acc: 0.552
# Epoch 94 loss: 0.635 acc: 0.641 val_loss: 0.689 val_acc: 0.544
# Epoch 95 loss: 0.634 acc: 0.636 val_loss: 0.689 val_acc: 0.554
# Epoch 96 loss: 0.630 acc: 0.639 val_loss: 0.690 val_acc: 0.544
# Epoch 97 loss: 0.631 acc: 0.639 val_loss: 0.688 val_acc: 0.550
# Epoch 98 loss: 0.635 acc: 0.644 val_loss: 0.691 val_acc: 0.544
# Epoch 99 loss: 0.631 acc: 0.646 val_loss: 0.687 val_acc: 0.543
# Epoch 100 loss: 0.633 acc: 0.645 val_loss: 0.691 val_acc: 0.545
# Epoch 101 loss: 0.632 acc: 0.644 val_loss: 0.692 val_acc: 0.547
# Epoch 102 loss: 0.628 acc: 0.641 val_loss: 0.687 val_acc: 0.543
# Epoch 103 loss: 0.633 acc: 0.647 val_loss: 0.687 val_acc: 0.547
# Epoch 104 loss: 0.630 acc: 0.643 val_loss: 0.689 val_acc: 0.548
# Epoch 105 loss: 0.631 acc: 0.645 val_loss: 0.691 val_acc: 0.548
# Epoch 106 loss: 0.631 acc: 0.644 val_loss: 0.688 val_acc: 0.555
# Epoch 107 loss: 0.633 acc: 0.648 val_loss: 0.690 val_acc: 0.555
# Epoch 108 loss: 0.631 acc: 0.649 val_loss: 0.690 val_acc: 0.548
# Epoch 109 loss: 0.628 acc: 0.641 val_loss: 0.686 val_acc: 0.547
# Epoch 110 loss: 0.629 acc: 0.646 val_loss: 0.692 val_acc: 0.547
# Epoch 111 loss: 0.634 acc: 0.656 val_loss: 0.689 val_acc: 0.551
# Epoch 112 loss: 0.631 acc: 0.650 val_loss: 0.689 val_acc: 0.548
# Epoch 113 loss: 0.633 acc: 0.644 val_loss: 0.688 val_acc: 0.548
# Epoch 114 loss: 0.632 acc: 0.647 val_loss: 0.690 val_acc: 0.559
# Epoch 115 loss: 0.629 acc: 0.648 val_loss: 0.689 val_acc: 0.549
# Epoch 116 loss: 0.631 acc: 0.651 val_loss: 0.686 val_acc: 0.552
# Epoch 117 loss: 0.626 acc: 0.653 val_loss: 0.687 val_acc: 0.549
# Epoch 118 loss: 0.630 acc: 0.642 val_loss: 0.688 val_acc: 0.552
# Epoch 119 loss: 0.629 acc: 0.649 val_loss: 0.691 val_acc: 0.556
# Epoch 120 loss: 0.633 acc: 0.644 val_loss: 0.685 val_acc: 0.555
# Epoch 121 loss: 0.631 acc: 0.645 val_loss: 0.690 val_acc: 0.557
# Epoch 122 loss: 0.628 acc: 0.647 val_loss: 0.687 val_acc: 0.549
# Epoch 123 loss: 0.628 acc: 0.646 val_loss: 0.685 val_acc: 0.553
# Epoch 124 loss: 0.625 acc: 0.650 val_loss: 0.688 val_acc: 0.555
# Epoch 125 loss: 0.626 acc: 0.651 val_loss: 0.687 val_acc: 0.549
# Epoch 126 loss: 0.631 acc: 0.652 val_loss: 0.686 val_acc: 0.554
# Epoch 127 loss: 0.625 acc: 0.644 val_loss: 0.686 val_acc: 0.558
# Epoch 128 loss: 0.627 acc: 0.651 val_loss: 0.690 val_acc: 0.551
# Epoch 129 loss: 0.625 acc: 0.650 val_loss: 0.686 val_acc: 0.558
# Epoch 130 loss: 0.626 acc: 0.648 val_loss: 0.689 val_acc: 0.555
# Epoch 131 loss: 0.625 acc: 0.651 val_loss: 0.684 val_acc: 0.556
# Epoch 132 loss: 0.626 acc: 0.643 val_loss: 0.692 val_acc: 0.548
# Epoch 133 loss: 0.628 acc: 0.651 val_loss: 0.684 val_acc: 0.557
# Epoch 134 loss: 0.627 acc: 0.645 val_loss: 0.687 val_acc: 0.552
# Epoch 135 loss: 0.626 acc: 0.652 val_loss: 0.686 val_acc: 0.553
# Epoch 136 loss: 0.623 acc: 0.648 val_loss: 0.685 val_acc: 0.558
# Epoch 137 loss: 0.624 acc: 0.654 val_loss: 0.688 val_acc: 0.553
# Epoch 138 loss: 0.625 acc: 0.645 val_loss: 0.686 val_acc: 0.561
# Epoch 139 loss: 0.625 acc: 0.649 val_loss: 0.682 val_acc: 0.561
# Epoch 140 loss: 0.626 acc: 0.652 val_loss: 0.687 val_acc: 0.559
# Epoch 141 loss: 0.626 acc: 0.658 val_loss: 0.685 val_acc: 0.557
# Epoch 142 loss: 0.627 acc: 0.654 val_loss: 0.683 val_acc: 0.562
# Epoch 143 loss: 0.626 acc: 0.653 val_loss: 0.684 val_acc: 0.562
# Epoch 144 loss: 0.625 acc: 0.658 val_loss: 0.683 val_acc: 0.551
# Epoch 145 loss: 0.625 acc: 0.653 val_loss: 0.682 val_acc: 0.560
# Epoch 146 loss: 0.625 acc: 0.653 val_loss: 0.680 val_acc: 0.559
# Epoch 147 loss: 0.623 acc: 0.653 val_loss: 0.683 val_acc: 0.559
# Epoch 148 loss: 0.625 acc: 0.658 val_loss: 0.683 val_acc: 0.555
# Epoch 149 loss: 0.622 acc: 0.655 val_loss: 0.686 val_acc: 0.559
# Epoch 150 loss: 0.623 acc: 0.661 val_loss: 0.681 val_acc: 0.563
# Epoch 151 loss: 0.622 acc: 0.657 val_loss: 0.682 val_acc: 0.562
# Epoch 152 loss: 0.622 acc: 0.658 val_loss: 0.681 val_acc: 0.558
# Epoch 153 loss: 0.622 acc: 0.652 val_loss: 0.690 val_acc: 0.565
# Epoch 154 loss: 0.620 acc: 0.655 val_loss: 0.683 val_acc: 0.559
# Epoch 155 loss: 0.622 acc: 0.655 val_loss: 0.684 val_acc: 0.564
# Epoch 156 loss: 0.622 acc: 0.659 val_loss: 0.682 val_acc: 0.565
# Epoch 157 loss: 0.623 acc: 0.659 val_loss: 0.680 val_acc: 0.560
# Epoch 158 loss: 0.623 acc: 0.653 val_loss: 0.682 val_acc: 0.569
# Epoch 159 loss: 0.625 acc: 0.656 val_loss: 0.683 val_acc: 0.568
# Epoch 160 loss: 0.621 acc: 0.661 val_loss: 0.688 val_acc: 0.560
# Epoch 161 loss: 0.622 acc: 0.657 val_loss: 0.683 val_acc: 0.564
# Epoch 162 loss: 0.618 acc: 0.661 val_loss: 0.681 val_acc: 0.562
# Epoch 163 loss: 0.618 acc: 0.659 val_loss: 0.681 val_acc: 0.568
# Epoch 164 loss: 0.620 acc: 0.661 val_loss: 0.685 val_acc: 0.562
# Epoch 165 loss: 0.621 acc: 0.659 val_loss: 0.683 val_acc: 0.556
# Epoch 166 loss: 0.624 acc: 0.658 val_loss: 0.679 val_acc: 0.567
# Epoch 167 loss: 0.618 acc: 0.656 val_loss: 0.681 val_acc: 0.566
# Epoch 168 loss: 0.621 acc: 0.665 val_loss: 0.683 val_acc: 0.566
# Epoch 169 loss: 0.620 acc: 0.660 val_loss: 0.677 val_acc: 0.565
# Epoch 170 loss: 0.620 acc: 0.654 val_loss: 0.678 val_acc: 0.567
# Epoch 171 loss: 0.622 acc: 0.655 val_loss: 0.680 val_acc: 0.562
# Epoch 172 loss: 0.620 acc: 0.658 val_loss: 0.680 val_acc: 0.569
# Epoch 173 loss: 0.620 acc: 0.661 val_loss: 0.681 val_acc: 0.571
# Epoch 174 loss: 0.620 acc: 0.668 val_loss: 0.682 val_acc: 0.560
# Epoch 175 loss: 0.619 acc: 0.654 val_loss: 0.677 val_acc: 0.567
# Epoch 176 loss: 0.619 acc: 0.660 val_loss: 0.679 val_acc: 0.570
# Epoch 177 loss: 0.617 acc: 0.664 val_loss: 0.681 val_acc: 0.564
# Epoch 178 loss: 0.621 acc: 0.666 val_loss: 0.684 val_acc: 0.572
# Epoch 179 loss: 0.621 acc: 0.659 val_loss: 0.678 val_acc: 0.572
# Epoch 180 loss: 0.618 acc: 0.663 val_loss: 0.678 val_acc: 0.568
# Epoch 181 loss: 0.616 acc: 0.668 val_loss: 0.677 val_acc: 0.569
# Epoch 182 loss: 0.620 acc: 0.666 val_loss: 0.686 val_acc: 0.562
# Epoch 183 loss: 0.618 acc: 0.657 val_loss: 0.678 val_acc: 0.564
# Epoch 184 loss: 0.619 acc: 0.665 val_loss: 0.678 val_acc: 0.572
# Epoch 185 loss: 0.620 acc: 0.660 val_loss: 0.675 val_acc: 0.571
# Epoch 186 loss: 0.616 acc: 0.664 val_loss: 0.675 val_acc: 0.566
# Epoch 187 loss: 0.617 acc: 0.661 val_loss: 0.676 val_acc: 0.570
# Epoch 188 loss: 0.618 acc: 0.659 val_loss: 0.676 val_acc: 0.569
# Epoch 189 loss: 0.615 acc: 0.660 val_loss: 0.678 val_acc: 0.569
# Epoch 190 loss: 0.616 acc: 0.661 val_loss: 0.674 val_acc: 0.569
# Epoch 191 loss: 0.619 acc: 0.663 val_loss: 0.672 val_acc: 0.574
# Epoch 192 loss: 0.616 acc: 0.672 val_loss: 0.678 val_acc: 0.572
# Epoch 193 loss: 0.616 acc: 0.665 val_loss: 0.680 val_acc: 0.573
# Epoch 194 loss: 0.618 acc: 0.667 val_loss: 0.679 val_acc: 0.569
# Epoch 195 loss: 0.620 acc: 0.659 val_loss: 0.677 val_acc: 0.569
# Epoch 196 loss: 0.617 acc: 0.667 val_loss: 0.676 val_acc: 0.573
# Epoch 197 loss: 0.612 acc: 0.662 val_loss: 0.676 val_acc: 0.570
# Epoch 198 loss: 0.616 acc: 0.668 val_loss: 0.676 val_acc: 0.572
# Epoch 199 loss: 0.615 acc: 0.670 val_loss: 0.677 val_acc: 0.573
# Epoch 200 loss: 0.619 acc: 0.664 val_loss: 0.676 val_acc: 0.572

# %% [markdown]
# As we might expect, logistic regression does not work well in identifying percolation. The concept is too complicated. We need a more complex network.
#
# From now on it is up to you to design a range of network architectures, and see how well they do on this apparently simple problem.

# %% [markdown]
# You can try numbers of hidden units ranging from 10 to 1000; you can try multiple layers (but with less than 100 neurons per layer - connecting a layer with 1000 neurons to another with 1000 neurons needs a million weights, which is too many for the CPU to handle in a reasonable time.)

# %% [markdown]
# When you define a larger model, start off with a small number of epochs - 2,say! you can then figure out how long a longer training will take.

# %% [markdown]
# See below for how to examine the structure of the history, and to plot curves of loss and accuracy during training for both the training and validation data.

# %%
# a nn with one hidden layer
class NN_one_hidden( nn.Module ):
    
    def __init__(self): 
        super(NN_one_hidden, self).__init__()
        self.layers = nn.Sequential( 
            nn.Flatten(), 
            nn.Linear(64,100), # try 100 hidden neurons
            nn.ReLU(),      # note that we need the brackets after nn.ReLU() and nn.Sigmoid(), because these 
                            # are classes that need to be instantiated
            nn.Linear(100,1),
            nn.Sigmoid())  # we are predicting only two classes, so we can use one sigmoid neuron as output
    
    def forward( self, x ): # computes the forward pass ... this one is particularly simple
        x = self.layers( x )
        return x

# %%
class NN_two_hidden( nn.Module ):
    
    def __init__(self): 
        super(NN_two_hidden, self).__init__()
        self.layers = nn.Sequential( 
            nn.Flatten(), 
            nn.Linear(64,100), # try 100 hidden neurons
            nn.ReLU(),      # note that we need the brackets after nn.ReLU() and nn.Sigmoid(), because these 
                            # are classes that need to be instantiated
            nn.Linear(100,100),
            nn.ReLU(),
            nn.Linear(100, 1),
            nn.Sigmoid())  # we are predicting only two classes, so we can use one sigmoid neuron as output
    
    def forward( self, x ): # computes the forward pass ... this one is particularly simple
        x = self.layers( x )
        return x

# %% [markdown]
# You will be defining many NN architectures (hopefully) so here is an encapsulation of the NN training cycle in a function.
#
# Experienced Python programmers may do it better than this...

# %%
# this function takes a neural-net class as argument, 
# together with the number of epochs, datasets, and batch-size
# I have written it like this to make sure you remember to initialise a new NN 
# (However you can redefine it to take a pre-initialised NN, so that you can repeatedly 
# train a NN with the same weights, as often as you want. )

def define_and_train( NN_class, n_epochs, training_set, test_set, batch_size=32, weight_decay=0.0 ):
    
    trainloader = torch.utils.data.DataLoader( training_set, batch_size=batch_size, shuffle=True)
    testloader = torch.utils.data.DataLoader( test_set, batch_size=batch_size, shuffle=True)

    thenet = NN_class()
    optimizer1 = optim.Adam( thenet.parameters(), weight_decay=weight_decay )
    
    train_acc = []
    val_acc = []
    train_loss = []
    val_loss = []
    
    for epoch in range(n_epochs): # number of times to loop over the dataset
        
        total_loss = 0 
        total_correct = 0 
        total_examples = 0 
        n_mini_batches = 0
    
        for i, mini_batch in enumerate( trainloader, 0 ):
            images, labels = mini_batch

            # zero the parameter gradients
            # all the parameters that are being updated are in the optimizer, 
            # so if we zero the gradients of all the tensors in the optimizer, 
            # that is the safest way to zero all the gradients
            optimizer1.zero_grad()

            outputs = thenet(images) # this is the forward pass

            loss = loss_function ( outputs, labels )

            loss.backward() # does the backward pass and computes all gradients

            optimizer1.step() # does one optimisation step

            n_mini_batches += 1 # keep track of number of minibatches, and collect the loss for each minibatch
            total_loss += loss.item() # remember that the loss is a zero-order tensor
            # so that to extract its value, we use .item(), as we cannot index as there are no dimensions

            # keep track of number of examples, and collect number correct in each minibatch
            total_correct += sum( ( outputs > 0.5 ) == ( labels > 0.5 ) ).item()
            total_examples += len( labels )

        # calculate statistics for each epoch and print them. 
        # You can alter this code to accumulate these statistics into lists/vectors and plot them
        epoch_training_accuracy = total_correct / total_examples
        epoch_training_loss = total_loss / n_mini_batches

        epoch_val_accuracy, epoch_val_loss = accuracy_and_loss( thenet, loss_function, testloader )

        print('Epoch %d loss: %.3f acc: %.3f val_loss: %.3f val_acc: %.3f'
              %(epoch+1, epoch_training_loss, epoch_training_accuracy, epoch_val_loss, epoch_val_accuracy   ))
        
        train_loss.append( epoch_training_loss )
        train_acc.append( epoch_training_accuracy )
        val_loss.append( epoch_val_loss )
        val_acc.append( epoch_val_accuracy )
    
    history = { 'train_loss': train_loss, 
                'train_acc': train_acc, 
                'val_loss': val_loss,
                'val_acc': val_acc }
    return ( history, thenet )

# %%
big_training_set = make_percolation_dataset( n_examples=10000 )

# %%
history1, net1 = define_and_train( NN_one_hidden, 50, training_set, test_set, batch_size=32, weight_decay=0.0000 )
# Out:
# Epoch 1 loss: 0.694 acc: 0.506 val_loss: 0.690 val_acc: 0.519
# Epoch 2 loss: 0.680 acc: 0.575 val_loss: 0.686 val_acc: 0.544
# Epoch 3 loss: 0.668 acc: 0.621 val_loss: 0.682 val_acc: 0.571
# Epoch 4 loss: 0.657 acc: 0.622 val_loss: 0.688 val_acc: 0.529
# Epoch 5 loss: 0.652 acc: 0.630 val_loss: 0.686 val_acc: 0.555
# Epoch 6 loss: 0.640 acc: 0.642 val_loss: 0.680 val_acc: 0.557
# Epoch 7 loss: 0.627 acc: 0.680 val_loss: 0.674 val_acc: 0.566
# Epoch 8 loss: 0.617 acc: 0.672 val_loss: 0.684 val_acc: 0.564
# Epoch 9 loss: 0.611 acc: 0.702 val_loss: 0.674 val_acc: 0.573
# Epoch 10 loss: 0.596 acc: 0.706 val_loss: 0.673 val_acc: 0.576
# Epoch 11 loss: 0.587 acc: 0.712 val_loss: 0.671 val_acc: 0.580
# Epoch 12 loss: 0.573 acc: 0.738 val_loss: 0.668 val_acc: 0.582
# Epoch 13 loss: 0.567 acc: 0.737 val_loss: 0.670 val_acc: 0.593
# Epoch 14 loss: 0.550 acc: 0.749 val_loss: 0.669 val_acc: 0.587
# Epoch 15 loss: 0.541 acc: 0.765 val_loss: 0.662 val_acc: 0.603
# Epoch 16 loss: 0.526 acc: 0.790 val_loss: 0.659 val_acc: 0.596
# Epoch 17 loss: 0.522 acc: 0.756 val_loss: 0.658 val_acc: 0.610
# Epoch 18 loss: 0.520 acc: 0.766 val_loss: 0.656 val_acc: 0.615
# Epoch 19 loss: 0.492 acc: 0.795 val_loss: 0.651 val_acc: 0.611
# Epoch 20 loss: 0.476 acc: 0.823 val_loss: 0.665 val_acc: 0.617
# Epoch 21 loss: 0.458 acc: 0.831 val_loss: 0.649 val_acc: 0.619
# Epoch 22 loss: 0.445 acc: 0.840 val_loss: 0.645 val_acc: 0.628
# Epoch 23 loss: 0.431 acc: 0.858 val_loss: 0.642 val_acc: 0.627
# Epoch 24 loss: 0.412 acc: 0.872 val_loss: 0.651 val_acc: 0.633
# Epoch 25 loss: 0.399 acc: 0.873 val_loss: 0.641 val_acc: 0.625
# Epoch 26 loss: 0.391 acc: 0.886 val_loss: 0.639 val_acc: 0.641
# Epoch 27 loss: 0.371 acc: 0.909 val_loss: 0.641 val_acc: 0.641
# Epoch 28 loss: 0.357 acc: 0.910 val_loss: 0.632 val_acc: 0.650
# Epoch 29 loss: 0.340 acc: 0.927 val_loss: 0.632 val_acc: 0.654
# Epoch 30 loss: 0.328 acc: 0.937 val_loss: 0.628 val_acc: 0.648
# Epoch 31 loss: 0.312 acc: 0.943 val_loss: 0.633 val_acc: 0.654
# Epoch 32 loss: 0.302 acc: 0.944 val_loss: 0.631 val_acc: 0.671
# Epoch 33 loss: 0.284 acc: 0.953 val_loss: 0.636 val_acc: 0.658
# Epoch 34 loss: 0.280 acc: 0.947 val_loss: 0.649 val_acc: 0.660
# Epoch 35 loss: 0.264 acc: 0.966 val_loss: 0.641 val_acc: 0.667
# Epoch 36 loss: 0.256 acc: 0.967 val_loss: 0.637 val_acc: 0.658
# Epoch 37 loss: 0.248 acc: 0.970 val_loss: 0.635 val_acc: 0.657
# Epoch 38 loss: 0.252 acc: 0.958 val_loss: 0.655 val_acc: 0.664
# Epoch 39 loss: 0.227 acc: 0.966 val_loss: 0.647 val_acc: 0.656
# Epoch 40 loss: 0.212 acc: 0.984 val_loss: 0.665 val_acc: 0.663
# Epoch 41 loss: 0.202 acc: 0.983 val_loss: 0.657 val_acc: 0.668
# Epoch 42 loss: 0.194 acc: 0.988 val_loss: 0.672 val_acc: 0.662
# Epoch 43 loss: 0.186 acc: 0.986 val_loss: 0.654 val_acc: 0.640
# Epoch 44 loss: 0.180 acc: 0.990 val_loss: 0.683 val_acc: 0.644
# Epoch 45 loss: 0.171 acc: 0.993 val_loss: 0.659 val_acc: 0.661
# Epoch 46 loss: 0.167 acc: 0.992 val_loss: 0.660 val_acc: 0.647
# Epoch 47 loss: 0.155 acc: 0.994 val_loss: 0.663 val_acc: 0.667
# Epoch 48 loss: 0.151 acc: 0.996 val_loss: 0.670 val_acc: 0.659
# Epoch 49 loss: 0.143 acc: 0.998 val_loss: 0.685 val_acc: 0.665
# Epoch 50 loss: 0.137 acc: 0.997 val_loss: 0.679 val_acc: 0.660

# %%
plt.plot( history1['train_loss'], label='train_loss')
plt.plot( history1['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot( history1['train_acc'], label='train_acc')
plt.plot( history1['val_acc'], label='val_acc')
plt.legend()

# %%
history2, net2 = define_and_train( NN_two_hidden, 50, training_set, test_set, batch_size=32, weight_decay=0.0000 )
# Out:
# Epoch 1 loss: 0.690 acc: 0.524 val_loss: 0.685 val_acc: 0.574
# Epoch 2 loss: 0.669 acc: 0.632 val_loss: 0.678 val_acc: 0.553
# Epoch 3 loss: 0.655 acc: 0.620 val_loss: 0.676 val_acc: 0.581
# Epoch 4 loss: 0.620 acc: 0.683 val_loss: 0.654 val_acc: 0.618
# Epoch 5 loss: 0.578 acc: 0.715 val_loss: 0.650 val_acc: 0.605
# Epoch 6 loss: 0.537 acc: 0.734 val_loss: 0.633 val_acc: 0.628
# Epoch 7 loss: 0.497 acc: 0.760 val_loss: 0.623 val_acc: 0.648
# Epoch 8 loss: 0.444 acc: 0.792 val_loss: 0.618 val_acc: 0.671
# Epoch 9 loss: 0.402 acc: 0.832 val_loss: 0.660 val_acc: 0.666
# Epoch 10 loss: 0.386 acc: 0.835 val_loss: 0.647 val_acc: 0.659
# Epoch 11 loss: 0.315 acc: 0.875 val_loss: 0.693 val_acc: 0.671
# Epoch 12 loss: 0.286 acc: 0.893 val_loss: 0.643 val_acc: 0.672
# Epoch 13 loss: 0.236 acc: 0.924 val_loss: 0.627 val_acc: 0.693
# Epoch 14 loss: 0.195 acc: 0.948 val_loss: 0.673 val_acc: 0.689
# Epoch 15 loss: 0.156 acc: 0.961 val_loss: 0.709 val_acc: 0.690
# Epoch 16 loss: 0.139 acc: 0.967 val_loss: 0.721 val_acc: 0.683
# Epoch 17 loss: 0.113 acc: 0.977 val_loss: 0.763 val_acc: 0.685
# Epoch 18 loss: 0.085 acc: 0.992 val_loss: 0.782 val_acc: 0.695
# Epoch 19 loss: 0.064 acc: 0.996 val_loss: 0.810 val_acc: 0.695
# Epoch 20 loss: 0.050 acc: 0.998 val_loss: 0.856 val_acc: 0.688
# Epoch 21 loss: 0.038 acc: 0.999 val_loss: 0.873 val_acc: 0.690
# Epoch 22 loss: 0.029 acc: 1.000 val_loss: 0.927 val_acc: 0.701
# Epoch 23 loss: 0.023 acc: 1.000 val_loss: 0.907 val_acc: 0.689
# Epoch 24 loss: 0.018 acc: 1.000 val_loss: 0.966 val_acc: 0.687
# Epoch 25 loss: 0.015 acc: 1.000 val_loss: 0.994 val_acc: 0.691
# Epoch 26 loss: 0.014 acc: 1.000 val_loss: 1.010 val_acc: 0.692
# Epoch 27 loss: 0.012 acc: 1.000 val_loss: 1.024 val_acc: 0.693
# Epoch 28 loss: 0.009 acc: 1.000 val_loss: 1.083 val_acc: 0.693
# Epoch 29 loss: 0.008 acc: 1.000 val_loss: 1.068 val_acc: 0.694
# Epoch 30 loss: 0.007 acc: 1.000 val_loss: 1.085 val_acc: 0.690
# Epoch 31 loss: 0.007 acc: 1.000 val_loss: 1.088 val_acc: 0.695
# Epoch 32 loss: 0.006 acc: 1.000 val_loss: 1.098 val_acc: 0.696
# Epoch 33 loss: 0.005 acc: 1.000 val_loss: 1.114 val_acc: 0.694
# Epoch 34 loss: 0.005 acc: 1.000 val_loss: 1.138 val_acc: 0.694
# Epoch 35 loss: 0.004 acc: 1.000 val_loss: 1.166 val_acc: 0.695
# Epoch 36 loss: 0.004 acc: 1.000 val_loss: 1.201 val_acc: 0.694
# Epoch 37 loss: 0.004 acc: 1.000 val_loss: 1.194 val_acc: 0.693
# Epoch 38 loss: 0.003 acc: 1.000 val_loss: 1.198 val_acc: 0.693
# Epoch 39 loss: 0.003 acc: 1.000 val_loss: 1.229 val_acc: 0.698
# Epoch 40 loss: 0.003 acc: 1.000 val_loss: 1.272 val_acc: 0.693
# Epoch 41 loss: 0.002 acc: 1.000 val_loss: 1.298 val_acc: 0.697
# Epoch 42 loss: 0.002 acc: 1.000 val_loss: 1.265 val_acc: 0.693
# Epoch 43 loss: 0.002 acc: 1.000 val_loss: 1.342 val_acc: 0.692
# Epoch 44 loss: 0.002 acc: 1.000 val_loss: 1.297 val_acc: 0.698
# Epoch 45 loss: 0.002 acc: 1.000 val_loss: 1.312 val_acc: 0.690
# Epoch 46 loss: 0.002 acc: 1.000 val_loss: 1.366 val_acc: 0.700
# Epoch 47 loss: 0.001 acc: 1.000 val_loss: 1.314 val_acc: 0.700
# Epoch 48 loss: 0.001 acc: 1.000 val_loss: 1.341 val_acc: 0.695
# Epoch 49 loss: 0.001 acc: 1.000 val_loss: 1.369 val_acc: 0.695
# Epoch 50 loss: 0.001 acc: 1.000 val_loss: 1.371 val_acc: 0.696

# %%
plt.plot( history2['train_loss'], label='train_loss')
plt.plot( history2['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot( history2['train_acc'], label='train_acc')
plt.plot( history2['val_acc'], label='val_acc')
plt.legend()

# %% [markdown]
# ### A convolutional model for detecting percolation
#
# Since percolation depends on local properties of the image, a better strategy may be to used a convolutional model, like the one defined below.
#
# After some messing about, I found that the model defined has reasonable (but not perfect) performance.  Please try to find a better one ! I was a little disappointed that I found that max-pooling layers seemed to slightly reduce performance, but you might find differently.
#
# Perhaps some 1x1 convolutions might improve performance?  I haven't tried them.
#
# Your challenge is to try this model out, and then to do some experiments. (To do experiments, you will need to be tidy: I suggest
#
# * For a small training set size (say 1000) examine the effect of different types and levels of regularisation. Try putting in `l1` and `l2` regularisation, and dropout (try each separately).
#     When adding `l1` or `l2` regularisation, a reasonable amount to add is in the region of
#     0.00001 to 0.001 .  Larger amounts of regularisation will just force all the weights towards zero.
#
# * How does validation error vary with training set size?  This is an important question!  Plot  log validation error versus  log training set size, in the range from 100 to 32000 (or 100000 if you have the time)  Plot a log-log graph, and see if you can identify a power law, visible as a straight(ish) line on the graph.

# %% [markdown]
# ### Constructing a convolutional model in Pytorch

# %% [markdown]
# We need to keep track of the sizes of the tensors as we build a convolutional net.
#
# One easy way to do this is to evaluate part of the network, using zeros as inputs, and look at the shape of the resulting tensor.

# %%
nn.Sequential( 
            nn.Conv2d(1,12,3,padding=1),
            nn.ReLU(), 
            nn.Conv2d(12,12,3,padding=1),
            nn.ReLU(),
            nn.Conv2d(12,2,3,padding=1), # idea: hopefully these will be connected to left edge, connected to right edge
            nn.ReLU() )( torch.zeros(1,1,8,8) ).shape
# Out:
# torch.Size([1, 2, 8, 8])

# %%
nn.Sequential( nn.Conv2d(1,12,3,padding=1), nn.ReLU() )( torch.zeros(1,1,8,8)).shape
# Out:
# torch.Size([1, 12, 8, 8])

# %%
class NN_convolutional1( nn.Module ):
    
    def __init__(self): 
        super(NN_convolutional1, self).__init__()
        self.layers = nn.Sequential( 
            nn.Conv2d(1,12,3,padding=1),
            nn.ReLU(), 
            nn.Conv2d(12,12,3,padding=1),
            nn.ReLU(),
            nn.Conv2d(12,2,3,padding=1), # idea: hopefully these will be connected to left edge, connected to right edge
            nn.ReLU(),
            nn.Flatten(),
            nn.Linear(128,12), # the 128 here is the number of elements in the tensor computed so far
            nn.ReLU(), 
            nn.Linear(12,1),
            nn.Sigmoid())  # we are predicting only two classes, so we can use one sigmoid neuron as output
    
    def forward( self, x ): # computes the forward pass ... this one is particularly simple
        x = self.layers( x )
        return x

# %%
print( NN_convolutional1() )
# Out:
# NN_convolutional1(
#   (layers): Sequential(
#     (0): Conv2d(1, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(12, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(12, 2, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): ReLU()
#     (6): Flatten()
#     (7): Linear(in_features=128, out_features=12, bias=True)
#     (8): ReLU()
#     (9): Linear(in_features=12, out_features=1, bias=True)
#     (10): Sigmoid()
#   )
# )

# %%
history3, net = define_and_train( NN_convolutional1, 50, training_set, test_set, batch_size=32, weight_decay=0.0000 )
# Out:
# Epoch 1 loss: 0.698 acc: 0.465 val_loss: 0.694 val_acc: 0.516
# Epoch 2 loss: 0.690 acc: 0.556 val_loss: 0.685 val_acc: 0.674
# Epoch 3 loss: 0.674 acc: 0.650 val_loss: 0.657 val_acc: 0.671
# Epoch 4 loss: 0.637 acc: 0.606 val_loss: 0.627 val_acc: 0.677
# Epoch 5 loss: 0.608 acc: 0.683 val_loss: 0.608 val_acc: 0.674
# Epoch 6 loss: 0.586 acc: 0.709 val_loss: 0.620 val_acc: 0.696
# Epoch 7 loss: 0.571 acc: 0.724 val_loss: 0.586 val_acc: 0.719
# Epoch 8 loss: 0.549 acc: 0.738 val_loss: 0.573 val_acc: 0.728
# Epoch 9 loss: 0.559 acc: 0.720 val_loss: 0.558 val_acc: 0.732
# Epoch 10 loss: 0.524 acc: 0.758 val_loss: 0.560 val_acc: 0.729
# Epoch 11 loss: 0.512 acc: 0.737 val_loss: 0.534 val_acc: 0.736
# Epoch 12 loss: 0.489 acc: 0.773 val_loss: 0.513 val_acc: 0.758
# Epoch 13 loss: 0.493 acc: 0.762 val_loss: 0.546 val_acc: 0.749
# Epoch 14 loss: 0.481 acc: 0.770 val_loss: 0.494 val_acc: 0.764
# Epoch 15 loss: 0.465 acc: 0.787 val_loss: 0.506 val_acc: 0.746
# Epoch 16 loss: 0.454 acc: 0.789 val_loss: 0.497 val_acc: 0.750
# Epoch 17 loss: 0.442 acc: 0.794 val_loss: 0.478 val_acc: 0.756
# Epoch 18 loss: 0.424 acc: 0.806 val_loss: 0.488 val_acc: 0.757
# Epoch 19 loss: 0.427 acc: 0.797 val_loss: 0.514 val_acc: 0.731
# Epoch 20 loss: 0.419 acc: 0.813 val_loss: 0.472 val_acc: 0.760
# Epoch 21 loss: 0.393 acc: 0.816 val_loss: 0.466 val_acc: 0.763
# Epoch 22 loss: 0.380 acc: 0.832 val_loss: 0.448 val_acc: 0.783
# Epoch 23 loss: 0.378 acc: 0.835 val_loss: 0.446 val_acc: 0.783
# Epoch 24 loss: 0.389 acc: 0.835 val_loss: 0.448 val_acc: 0.793
# Epoch 25 loss: 0.360 acc: 0.834 val_loss: 0.435 val_acc: 0.796
# Epoch 26 loss: 0.346 acc: 0.848 val_loss: 0.431 val_acc: 0.794
# Epoch 27 loss: 0.337 acc: 0.863 val_loss: 0.515 val_acc: 0.752
# Epoch 28 loss: 0.339 acc: 0.846 val_loss: 0.445 val_acc: 0.800
# Epoch 29 loss: 0.321 acc: 0.858 val_loss: 0.447 val_acc: 0.809
# Epoch 30 loss: 0.305 acc: 0.864 val_loss: 0.455 val_acc: 0.784
# Epoch 31 loss: 0.308 acc: 0.857 val_loss: 0.418 val_acc: 0.809
# Epoch 32 loss: 0.292 acc: 0.871 val_loss: 0.498 val_acc: 0.794
# Epoch 33 loss: 0.315 acc: 0.869 val_loss: 0.427 val_acc: 0.791
# Epoch 34 loss: 0.296 acc: 0.875 val_loss: 0.447 val_acc: 0.807
# Epoch 35 loss: 0.318 acc: 0.858 val_loss: 0.532 val_acc: 0.750
# Epoch 36 loss: 0.306 acc: 0.874 val_loss: 0.413 val_acc: 0.800
# Epoch 37 loss: 0.273 acc: 0.885 val_loss: 0.402 val_acc: 0.811
# Epoch 38 loss: 0.260 acc: 0.896 val_loss: 0.405 val_acc: 0.809
# Epoch 39 loss: 0.295 acc: 0.860 val_loss: 0.410 val_acc: 0.826
# Epoch 40 loss: 0.275 acc: 0.875 val_loss: 0.408 val_acc: 0.806
# Epoch 41 loss: 0.257 acc: 0.903 val_loss: 0.417 val_acc: 0.803
# Epoch 42 loss: 0.251 acc: 0.897 val_loss: 0.448 val_acc: 0.789
# Epoch 43 loss: 0.281 acc: 0.862 val_loss: 0.401 val_acc: 0.825
# Epoch 44 loss: 0.251 acc: 0.888 val_loss: 0.401 val_acc: 0.828
# Epoch 45 loss: 0.237 acc: 0.904 val_loss: 0.411 val_acc: 0.828
# Epoch 46 loss: 0.243 acc: 0.890 val_loss: 0.438 val_acc: 0.797
# Epoch 47 loss: 0.229 acc: 0.907 val_loss: 0.394 val_acc: 0.815
# Epoch 48 loss: 0.236 acc: 0.898 val_loss: 0.398 val_acc: 0.834
# Epoch 49 loss: 0.217 acc: 0.910 val_loss: 0.399 val_acc: 0.827
# Epoch 50 loss: 0.233 acc: 0.907 val_loss: 0.436 val_acc: 0.803

# %%
plt.plot( history3['train_loss'], label='train_loss')
plt.plot( history3['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot( history3['train_acc'], label='train_acc')
plt.plot( history3['val_acc'], label='val_acc')
plt.legend()

# %% [markdown]
# # The Golden Rules of Model Search
#
# Step 1: what error rate do you expect a good model to have?  (It may be zero, or there may be some residual error rate - perhaps even humans do not perform perfectly.) Call this error rate the *ideal error rate*
#
# Step 2: define and fit a model and examine the training and validation errors.
#
# Step 3a: If the model does not fit the training set well, then the model does not have enough capacity (flexibility).  Add more complexity in some way  - more neurons, more layers. It is of course best to do this in an insightful way !  Go to step 2.
#
# Step 3b: If the model *does* fit the training set well, but there is higher error on the validation set, then the model is overfitted. Do either (or both)  of:
#
#     * Use more training data
#
#     * Add more regularisation to the model (in an insightful way).
#
# Go to step 2.
#
#
# These golden rules are not very specific, but they are a lot better than simply making random changes to the model and hoping that it gets better.

# %% [markdown]
# ### Power law for convolutional model

# %%
# actually plot the training set size vs validation error
# these are actual error-rates with a previous (more complex) convolutional model
plt.loglog([1000,2000,4000,8000,16000], [0.0636,0.0330,0.0130,0.006,0.0046])

# %% [markdown]
# # Inspection of errors

# %% [markdown]
#  Exercise: find the errors on the training and validation sets, and inspect them.
#
#  Can you say anything useful about what your net is doing wrong?
#
#  I found that the false-negatives -- the percolating examples that the net thought did not percolate -- tended to have long percolating paths, as one might expect.
#
#  But I could not see any regularities in the false-positive -- the non-percolating examples that the net thought would percolate -- at all.

# %% [markdown]
# # Test examples for percolation

# %% [markdown]
# This is a test-set of some specially constructed examples that are designed to be 'corner cases' on which to test your network.

# %%
test_all_zeros = np.zeros([8,8])
plt.imshow(test_all_zeros)
plt.colorbar()

# %%
test_all_ones = np.ones([8,8])
plt.imshow(test_all_ones)
plt.colorbar()

# %%
test_eye = np.eye(8) # this should be an easy example
plt.imshow(test_eye)
plt.colorbar()

# %%
test_inverse_eye = 1 - np.eye(8)
plt.imshow( test_inverse_eye )

# %%
test_inverse_eye_connected = 1 - np.eye(8)
test_inverse_eye_connected[4,4] = 1
plt.imshow( test_inverse_eye_connected )

# %%
test_inverse_eye_connected_bottom = 1 - np.eye(8)
test_inverse_eye_connected_bottom[7,7] = 1
plt.imshow( test_inverse_eye_connected_bottom )

# %%
test_inverse_eye_connected_top = 1 - np.eye(8)
test_inverse_eye_connected_top[0,0] = 1
plt.imshow( test_inverse_eye_connected_top )

# %%
test_middle_row = np.zeros([8,8])
test_middle_row[3,:] = 1
plt.imshow(test_middle_row)

# %%
test_top_row = np.zeros([8,8])
test_top_row[0,:] = 1
plt.imshow(test_top_row)

# %%
test_bottom_row = np.zeros([8,8])
test_bottom_row[-1,:] = 1
plt.imshow(test_bottom_row)

# %%
test_vertical_column_disconnect = np.ones([8,8])
test_vertical_column_disconnect[:,4] = 0 
plt.imshow(test_vertical_column_disconnect)

# %%
test_row_with_gap = np.zeros([8,8])
test_row_with_gap[3,:] = 1
test_row_with_gap[3,4] = 0 
plt.imshow(test_row_with_gap)

# %%
test_two_rows_nearly = np.zeros([8,8])
test_two_rows_nearly[2,:7] = 1
test_two_rows_nearly[4,1:] = 1
plt.imshow(test_two_rows_nearly)

# %%
test_four_rows_nearly = np.zeros([8,8])
test_four_rows_nearly[0,:7] = 1
test_four_rows_nearly[2,1:] = 1
test_four_rows_nearly[4,:7] = 1
test_four_rows_nearly[6,1:] = 1
plt.imshow(test_four_rows_nearly)

# %%
test_dog_leg = np.zeros([8,8])
test_dog_leg[1,:5] = 1
test_dog_leg[2:7,4] = 1
test_dog_leg[6,4:] = 1
plt.imshow(test_dog_leg)

# %%
test_dog_leg_back = np.zeros([8,8])
test_dog_leg_back[1,:5] = 1
test_dog_leg_back[2:5,4] = 1
test_dog_leg_back[4:6,3] = 1
test_dog_leg_back[6,3:] = 1
plt.imshow(test_dog_leg_back)

# %%
test_long_path = np.zeros([8,8])
test_long_path[1,:7] = 1
test_long_path[2:4,6] = 1
test_long_path[4,1:7] = 1
test_long_path[5:7,1] = 1
test_long_path[6,1:] = 1
plt.imshow(test_long_path)

# %%
test_longer_path = np.zeros([8,8])
test_longer_path[0,:7] = 1
test_longer_path[1:3,6] = 1
test_longer_path[2,1:7] = 1
test_longer_path[3:8,1] = 1
test_longer_path[7,2:4] = 1
test_longer_path[4:7,3] = 1
test_longer_path[4,4:6] = 1
test_longer_path[5:8,5] = 1
test_longer_path[7,6:8] = 1
plt.imshow(test_longer_path)

# %%
test_vertical_stripes = np.zeros([8,8])
test_vertical_stripes[:,1] = 1
test_vertical_stripes[:,3] = 1
test_vertical_stripes[:,5] = 1
test_vertical_stripes[:,7] = 1
plt.imshow(test_vertical_stripes)

# %%
test_vertical_stripes_connected_1 = np.zeros([8,8])
test_vertical_stripes_connected_1[:,1] = 1
test_vertical_stripes_connected_1[:,3] = 1
test_vertical_stripes_connected_1[:,5] = 1
test_vertical_stripes_connected_1[:,7] = 1
test_vertical_stripes_connected_1[7,0] = 1
test_vertical_stripes_connected_1[0,2] = 1
test_vertical_stripes_connected_1[7,4] = 1
test_vertical_stripes_connected_1[0,6] = 1

plt.imshow(test_vertical_stripes_connected_1)

# %%
test_vertical_stripes_connected_2 = np.zeros([8,8])
test_vertical_stripes_connected_2[:,1] = 1
test_vertical_stripes_connected_2[:,3] = 1
test_vertical_stripes_connected_2[:,5] = 1
test_vertical_stripes_connected_2[:,7] = 1
test_vertical_stripes_connected_2[6,0] = 1
test_vertical_stripes_connected_2[1,2] = 1
test_vertical_stripes_connected_2[6,4] = 1
test_vertical_stripes_connected_2[1,6] = 1

plt.imshow(test_vertical_stripes_connected_2)

# %%
test_vertical_stripes_disconnected_1 = np.zeros([8,8])
test_vertical_stripes_disconnected_1[:,1] = 1
test_vertical_stripes_disconnected_1[:,3] = 1
test_vertical_stripes_disconnected_1[:,5] = 1
test_vertical_stripes_disconnected_1[:,7] = 1
test_vertical_stripes_disconnected_1[6,0] = 1
test_vertical_stripes_disconnected_1[1,2] = 1
test_vertical_stripes_disconnected_1[6,2] = 1
test_vertical_stripes_disconnected_1[1,6] = 1

plt.imshow(test_vertical_stripes_disconnected_1)

# %%
test_vertical_stripes_connected_3 = np.zeros([8,8])
test_vertical_stripes_connected_3[:,1] = 1
test_vertical_stripes_connected_3[:,3] = 1
test_vertical_stripes_connected_3[:,5] = 1
test_vertical_stripes_connected_3[:,7] = 1
test_vertical_stripes_connected_3[4,:] = 1

plt.imshow(test_vertical_stripes_connected_3)

# %%
test_examples = [test_all_ones,
                 test_eye, 
                 test_inverse_eye,
                 test_inverse_eye_connected,
                 test_inverse_eye_connected_bottom,
                 test_inverse_eye_connected_top,
                 test_middle_row, test_top_row, 
                 test_bottom_row, 
                 test_vertical_column_disconnect,
                 test_row_with_gap, 
                 test_two_rows_nearly, 
                 test_four_rows_nearly, 
                 test_dog_leg, 
                 test_dog_leg_back,
                 test_long_path, 
                 test_longer_path, 
                 test_vertical_stripes,
                 test_vertical_stripes_connected_1,
                 test_vertical_stripes_connected_2,
                 test_vertical_stripes_connected_3,
                 test_vertical_stripes_disconnected_1]

# %%
[ percolate(x) for x in test_examples ]
# Out:
# [True,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  False,
#  True,
#  True,
#  True,
#  False]
